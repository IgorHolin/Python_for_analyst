# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/igorp/Downloads/laptops.csv', sep=';')
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %% [markdown]
# ### Вывести первые 5 строк

# %%
df.head(5)
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %% [markdown]
# ### Посмотреть на описание признаков и их содержание

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.dtypes
# Out:
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
df.describe(include='object')
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %%
df['Price_euros'].mean()
# Out:
# 1123.6869915579432

# %%
df['Company'].value_counts().head(3)
# Out:
# Dell      297
# Lenovo    297
# HP        274
# Name: Company, dtype: int64

# %%
df.sort_values('Price_euros', ascending=False).iloc[0]
# Out:
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                32GB
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                           3.49kg
# Price_euros                                      6099.0
# Name: 196, dtype: object

# %%
df[df['Inches'] == df['Inches'].min()][['Company','Inches','Price_euros']]
# Out:
#      Company  Inches  Price_euros
# 50    Lenovo    10.1       319.00
# 1082  Lenovo    10.1       646.27
# 1114  Lenovo    10.1       549.00
# 1126  Lenovo    10.1       479.00

# %%
x = df[df['Company'] == 'HP'].max()
x
# x.sort_values('Price_euros', ascending=False).iloc[0]
# Out:
# Company                                        HP
# Product                                  Zbook 17
# TypeName                              Workstation
# Inches                                       17.3
# ScreenResolution            Touchscreen 2560x1440
# Cpu                 Intel Xeon E3-1535M v5 2.9GHz
# Ram                                           8GB
# Memory                                    8GB SSD
# Gpu                          Nvidia Quadro M3000M
# OpSys                                   Windows 7
# Weight                                        3kg
# Price_euros                                4389.0
# dtype: object

# %%
df[(df['TypeName'] == 'Ultrabook') & (df['Ram'] == '8GB')].shape[0]
# Out:
# 140

# %%
df[((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] <= 500)].head(13)
# Out:
#      Company                                   Product  TypeName  Inches  \
# 74      Acer                             Aspire E5-475  Notebook    14.0
# 175     Dell                             Inspiron 3567  Notebook    15.6
# 256       HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook    15.6
# 292       HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook    17.3
# 313     Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook    15.6
# 365       HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook    15.6
# 571       HP            14-am079na (N3710/8GB/2TB/W10)  Notebook    14.0
# 595   Lenovo                         IdeaPad 110-15ISK  Notebook    15.6
# 634     Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook    15.6
# 702   Lenovo                         IdeaPad 320-15ABR  Notebook    15.6
# 1057    Acer                            Aspire ES1-523  Notebook    15.6
# 1163  Lenovo                         IdeaPad 310-15ISK  Notebook    15.6
# ...

# %%
df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & ~(df['Inches'] == 15.6)].sort_values('Price_euros', ascending=True)
# Out:
#      Company        Product TypeName  Inches   ScreenResolution  \
# 330      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 724      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393      MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 1156     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917      MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# 724   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1348.48
# ...

# %%
x = df['Price_euros'][df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz'].mean()
y = df['Price_euros'][df['Cpu'] == 'Intel Core i7 7600U 2.8GHz'].mean() 
x,y
# Out:
# (1760.4084246575342, 1915.710769230769)

# %%
df['Weight'] = df['Weight'].str.replace('kg','')
df['Weight'] = df['Weight'].astype('float')
df.sort_values('Weight',ascending=True).iloc[0]
# Out:
# Company                                      Lenovo
# Product                                   Yoga Book
# TypeName                         2 in 1 Convertible
# Inches                                         10.1
# ScreenResolution    IPS Panel Touchscreen 1920x1200
# Cpu                     Intel Atom x5-Z8550 1.44GHz
# Ram                                             4GB
# Memory                           64GB Flash Storage
# Gpu                           Intel HD Graphics 400
# OpSys                                    Windows 10
# Weight                                         0.69
# Price_euros                                  646.27
# Name: 1082, dtype: object
